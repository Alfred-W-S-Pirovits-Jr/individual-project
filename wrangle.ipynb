# %%
import os
import pandas as pd
import seaborn as sns
import env
# import acquire
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from datetime import datetime

# %%
plt.figure(figsize=(10,6))

# sunspots.resample('D').mean().sunspots['Monthly Mean Total Sunspot Number'].plot(label='daily')
# sunspots.resample('W').mean().sunspots['Monthly Mean Total Sunspot Number'](label='weekly')
sunspots.resample('M').mean().Monthly_Mean_Total_Sunspot_Number.plot(label='monthly')
sunspots.resample('Y').mean().Monthly_Mean_Total_Sunspot_Number.plot(label='yearly')


plt.title('Sunspots over time')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 plt.figure(figsize=(10,6))
#       3 # sunspots.resample('D').mean().sunspots['Monthly Mean Total Sunspot Number'].plot(label='daily')
#       4 # sunspots.resample('W').mean().sunspots['Monthly Mean Total Sunspot Number'](label='weekly')
# ----> 5 sunspots.resample('M').mean().Monthly_Mean_Total_Sunspot_Number.plot(label='monthly')
#       6 sunspots.resample('Y').mean().Monthly_Mean_Total_Sunspot_Number.plot(label='yearly')
#       9 plt.title('Sunspots over time')
#
# NameError: name 'sunspots' is not defined

# %%
y = sunspots.Monthly_Mean_Total_Sunspot_Number.resample('Y').mean()

result = sm.tsa.seasonal_decompose(y)

decomposition = pd.DataFrame({
    'y': result.observed,
    'trend': result.trend,
    'seasonal': result.seasonal,
    'resid': result.resid
})

decomposition['trend_centered'] = decomposition.trend - decomposition.trend.mean()
decomposition[['trend_centered', 'seasonal', 'resid']].plot();

# %%
column_list = ['FL_DATE', 'OP_CARRIER', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY']
flights2009 = pd.read_csv('airline delay analysis/2009.csv', usecols=column_list)

# %%
flights2009 = flights2009[flights2009['OP_CARRIER'] == 'UA']

# %%
print(flights2009.size)
flights2009.isna().sum()
# Out:
# 2633904
# FL_DATE                     0
# OP_CARRIER                  0
# CARRIER_DELAY          313510
# WEATHER_DELAY          313510
# NAS_DELAY              313510
# SECURITY_DELAY         313510
# LATE_AIRCRAFT_DELAY    313510
# dtype: int64

# %%
flights2009
# Out:
#             FL_DATE OP_CARRIER  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 3102     2009-01-01         UA            NaN            NaN        NaN
# 3103     2009-01-01         UA            NaN            NaN        NaN
# 3104     2009-01-01         UA            NaN            NaN        NaN
# 3105     2009-01-01         UA            NaN            NaN        NaN
# 3106     2009-01-01         UA            NaN            NaN        NaN
# ...             ...        ...            ...            ...        ...
# 6421229  2009-12-31         UA           42.0            0.0        9.0
# 6421230  2009-12-31         UA            NaN            NaN        NaN
# 6421231  2009-12-31         UA           63.0            0.0       14.0
# 6421232  2009-12-31         UA            NaN            NaN        NaN
# 6421233  2009-12-31         UA            0.0            0.0        0.0
#
#          SECURITY_DELAY  LATE_AIRCRAFT_DELAY
# 3102                NaN                  NaN
# 3103                NaN                  NaN
# 3104                NaN                  NaN
# 3105                NaN                  NaN
# 3106                NaN                  NaN
# ...                 ...                  ...
# 6421229             0.0                  0.0
# 6421230             NaN                  NaN
# 6421231             0.0                  0.0
# 6421232             NaN                  NaN
# 6421233             0.0                 59.0
#
# [376272 rows x 7 columns]

# %%
flights2010 = pd.read_csv('airline delay analysis/2010.csv', usecols=column_list)

# %%
flights2010 = flights2010[flights2010['OP_CARRIER'] == 'UA']

# %%
flights2010
# Out:
#             FL_DATE OP_CARRIER  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 1826     2010-01-01         UA           26.0            0.0       15.0
# 1827     2010-01-01         UA            NaN            NaN        NaN
# 1828     2010-01-01         UA            NaN            NaN        NaN
# 1829     2010-01-01         UA            NaN            NaN        NaN
# 1830     2010-01-01         UA            NaN            NaN        NaN
# ...             ...        ...            ...            ...        ...
# 6449043  2010-12-31         UA            NaN            NaN        NaN
# 6449044  2010-12-31         UA            NaN            NaN        NaN
# 6449045  2010-12-31         UA            NaN            NaN        NaN
# 6449046  2010-12-31         UA            0.0            0.0       34.0
# 6449047  2010-12-31         UA            0.0            0.0       15.0
#
#          SECURITY_DELAY  LATE_AIRCRAFT_DELAY
# 1826                0.0                  0.0
# 1827                NaN                  NaN
# 1828                NaN                  NaN
# 1829                NaN                  NaN
# 1830                NaN                  NaN
# ...                 ...                  ...
# 6449043             NaN                  NaN
# 6449044             NaN                  NaN
# 6449045             NaN                  NaN
# 6449046             0.0                  0.0
# 6449047             0.0                  0.0
#
# [343081 rows x 7 columns]

# %%
flights2009.append(flights2010)
# Out:
# /var/folders/jv/wt_gjk6n74bcbzwl91qys7sr0000gn/T/ipykernel_3039/4259961005.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   flights2009.append(flights2010)
#             FL_DATE OP_CARRIER  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 3102     2009-01-01         UA            NaN            NaN        NaN
# 3103     2009-01-01         UA            NaN            NaN        NaN
# 3104     2009-01-01         UA            NaN            NaN        NaN
# 3105     2009-01-01         UA            NaN            NaN        NaN
# 3106     2009-01-01         UA            NaN            NaN        NaN
# ...             ...        ...            ...            ...        ...
# 6449043  2010-12-31         UA            NaN            NaN        NaN
# 6449044  2010-12-31         UA            NaN            NaN        NaN
# 6449045  2010-12-31         UA            NaN            NaN        NaN
# 6449046  2010-12-31         UA            0.0            0.0       34.0
# 6449047  2010-12-31         UA            0.0            0.0       15.0
#
#          SECURITY_DELAY  LATE_AIRCRAFT_DELAY
# 3102                NaN                  NaN
# 3103                NaN                  NaN
# 3104                NaN                  NaN
# 3105                NaN                  NaN
# 3106                NaN                  NaN
# ...                 ...                  ...
# 6449043             NaN                  NaN
# 6449044             NaN                  NaN
# 6449045             NaN                  NaN
# 6449046             0.0                  0.0
# 6449047             0.0                  0.0
#
# [719353 rows x 7 columns]

# %%
column_list = ['FL_DATE', 'OP_UNIQUE_CARRIER', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY']    
flights2019 = pd.read_csv(f'airline delay analysis/2019.csv', usecols=column_list) 
flights2019 = flights2019.rename(columns={'OP_UNIQUE_CARRIER':'OP_CARRIER'})
flights2019 = flights2019[flights2019['OP_CARRIER'] == 'UA']

# %%
flights2019
# Out:
#             FL_DATE OP_CARRIER  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 4695     2019-01-01         UA            0.0            0.0       34.0
# 4696     2019-01-01         UA            NaN            NaN        NaN
# 4697     2019-01-01         UA            NaN            NaN        NaN
# 4698     2019-01-01         UA            NaN            NaN        NaN
# 4699     2019-01-01         UA            NaN            NaN        NaN
# ...             ...        ...            ...            ...        ...
# 7417301  2019-12-31         UA            NaN            NaN        NaN
# 7417302  2019-12-31         UA            NaN            NaN        NaN
# 7417303  2019-12-31         UA            NaN            NaN        NaN
# 7417304  2019-12-31         UA            NaN            NaN        NaN
# 7417305  2019-12-31         UA            NaN            NaN        NaN
#
#          SECURITY_DELAY  LATE_AIRCRAFT_DELAY
# 4695                0.0                  0.0
# 4696                NaN                  NaN
# 4697                NaN                  NaN
# 4698                NaN                  NaN
# 4699                NaN                  NaN
# ...                 ...                  ...
# 7417301             NaN                  NaN
# 7417302             NaN                  NaN
# 7417303             NaN                  NaN
# 7417304             NaN                  NaN
# 7417305             NaN                  NaN
#
# [625910 rows x 7 columns]

# %%
def pull_airline_data(airline = 'UA') -> pd.DataFrame:
    filename = f'{airline}.csv'
    
    #if this airline has already been pulled it will be saved as csv
    if os.path.isfile(filename):
        return pd.read_csv(filename, index_col=[0])
    
    #Pull and Create the df
    else:
        #Create the list of columns # want to pull from the dataframe
        column_list = ['FL_DATE', 'OP_CARRIER', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY']

        #Pull the abridged columns in a loop for 2009-2018 creating an empth df outside the loop
        flights = pd.DataFrame()
        for i in range(2009, 2019):
            # read each csv and pull the columns of interest
            flightsi = pd.read_csv(f'airline delay analysis/{i}.csv', usecols=column_list)
            # Mask for specific airline which in this case is United Airlines or UA
            flightsi = flightsi[flightsi['OP_CARRIER'] == airline]
            #links all the df's together vertically into one
            flights = flights.append(flightsi)

        #2019 dataset slightly different with less columns and OP_UNIQUE_CARRIER instead of OP_CARRIER
        column_list = ['FL_DATE', 'OP_UNIQUE_CARRIER', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY']    
        #SAME as above except renames the column in order to append (MVP SOLUTION)
        flights2019 = pd.read_csv(f'airline delay analysis/2019.csv', usecols=column_list) 
        flights2019 = flights2019.rename(columns={'OP_UNIQUE_CARRIER':'OP_CARRIER'})
        flights2019 = flights2019[flights2019['OP_CARRIER'] == 'UA']
        flights = flights.append(flights2019)
        
        #create the csv
        flights.to_csv(f'{airline}.csv')
        
        #return the db
        return flights

# %%
flights = pull_airline_data('DL')

# %%
flights
# Out:
#             FL_DATE OP_CARRIER  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 15209    2009-01-01         DL            6.0            0.0        0.0
# 15210    2009-01-01         DL            NaN            NaN        NaN
# 15211    2009-01-01         DL            0.0            0.0        0.0
# 15212    2009-01-01         DL            0.0            0.0        0.0
# 15213    2009-01-01         DL            NaN            NaN        NaN
# ...             ...        ...            ...            ...        ...
# 7417301  2019-12-31         UA            NaN            NaN        NaN
# 7417302  2019-12-31         UA            NaN            NaN        NaN
# 7417303  2019-12-31         UA            NaN            NaN        NaN
# 7417304  2019-12-31         UA            NaN            NaN        NaN
# 7417305  2019-12-31         UA            NaN            NaN        NaN
#
#          SECURITY_DELAY  LATE_AIRCRAFT_DELAY
# 15209               0.0                 52.0
# 15210               NaN                  NaN
# 15211               0.0                 92.0
# 15212               0.0                264.0
# 15213               NaN                  NaN
# ...                 ...                  ...
# 7417301             NaN                  NaN
# 7417302             NaN                  NaN
# 7417303             NaN                  NaN
# 7417304             NaN                  NaN
# 7417305             NaN                  NaN
#
# [8467790 rows x 7 columns]

# %% [markdown]
# ### Fills in the na values as 0 because na means 0 delay for given cause

# %%
flights.fillna(0, inplace=True)

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8467790 entries, 15209 to 7417305
# Data columns (total 7 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   FL_DATE              object
#  1   OP_CARRIER           object
#  2   CARRIER_DELAY        float64
#  3   WEATHER_DELAY        float64
#  4   NAS_DELAY            float64
#  5   SECURITY_DELAY       float64
#  6   LATE_AIRCRAFT_DELAY  float64
# dtypes: float64(5), object(2)
# memory usage: 516.8+ MB

# %%
flights.FL_DATE = flights.FL_DATE.astype('datetime64')
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8467790 entries, 15209 to 7417305
# Data columns (total 7 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   FL_DATE              datetime64[ns]
#  1   OP_CARRIER           object
#  2   CARRIER_DELAY        float64
#  3   WEATHER_DELAY        float64
#  4   NAS_DELAY            float64
#  5   SECURITY_DELAY       float64
#  6   LATE_AIRCRAFT_DELAY  float64
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 516.8+ MB

# %%
flights = flights.set_index('FL_DATE')

# %%
flights
# Out:
#            OP_CARRIER  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# FL_DATE
# 2009-01-01         DL            6.0            0.0        0.0
# 2009-01-01         DL            0.0            0.0        0.0
# 2009-01-01         DL            0.0            0.0        0.0
# 2009-01-01         DL            0.0            0.0        0.0
# 2009-01-01         DL            0.0            0.0        0.0
# ...               ...            ...            ...        ...
# 2019-12-31         UA            0.0            0.0        0.0
# 2019-12-31         UA            0.0            0.0        0.0
# 2019-12-31         UA            0.0            0.0        0.0
# 2019-12-31         UA            0.0            0.0        0.0
# 2019-12-31         UA            0.0            0.0        0.0
#
#             SECURITY_DELAY  LATE_AIRCRAFT_DELAY
# FL_DATE
# 2009-01-01             0.0                 52.0
# 2009-01-01             0.0                  0.0
# 2009-01-01             0.0                 92.0
# 2009-01-01             0.0                264.0
# 2009-01-01             0.0                  0.0
# ...                    ...                  ...
# 2019-12-31             0.0                  0.0
# 2019-12-31             0.0                  0.0
# 2019-12-31             0.0                  0.0
# 2019-12-31             0.0                  0.0
# 2019-12-31             0.0                  0.0
#
# [8467790 rows x 6 columns]

# %%
flights['total_delays'] = flights.CARRIER_DELAY + flights.WEATHER_DELAY + flights.NAS_DELAY + flights.SECURITY_DELAY + flights.LATE_AIRCRAFT_DELAY

# %%
flights
# Out:
#            OP_CARRIER  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# FL_DATE
# 2009-01-01         DL            6.0            0.0        0.0
# 2009-01-01         DL            0.0            0.0        0.0
# 2009-01-01         DL            0.0            0.0        0.0
# 2009-01-01         DL            0.0            0.0        0.0
# 2009-01-01         DL            0.0            0.0        0.0
# ...               ...            ...            ...        ...
# 2019-12-31         UA            0.0            0.0        0.0
# 2019-12-31         UA            0.0            0.0        0.0
# 2019-12-31         UA            0.0            0.0        0.0
# 2019-12-31         UA            0.0            0.0        0.0
# 2019-12-31         UA            0.0            0.0        0.0
#
#             SECURITY_DELAY  LATE_AIRCRAFT_DELAY  total_delays
# FL_DATE
# 2009-01-01             0.0                 52.0          58.0
# 2009-01-01             0.0                  0.0           0.0
# 2009-01-01             0.0                 92.0          92.0
# 2009-01-01             0.0                264.0         264.0
# 2009-01-01             0.0                  0.0           0.0
# ...                    ...                  ...           ...
# 2019-12-31             0.0                  0.0           0.0
# 2019-12-31             0.0                  0.0           0.0
# 2019-12-31             0.0                  0.0           0.0
# 2019-12-31             0.0                  0.0           0.0
# 2019-12-31             0.0                  0.0           0.0
#
# [8467790 rows x 7 columns]

# %%
flights = flights.drop(columns=['OP_CARRIER', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY'])

# %%
flights
# Out:
#             total_delays
# FL_DATE
# 2009-01-01          58.0
# 2009-01-01           0.0
# 2009-01-01          92.0
# 2009-01-01         264.0
# 2009-01-01           0.0
# ...                  ...
# 2019-12-31           0.0
# 2019-12-31           0.0
# 2019-12-31           0.0
# 2019-12-31           0.0
# 2019-12-31           0.0
#
# [8467790 rows x 1 columns]

# %%
flights.index.value_counts()
# Out:
# 2011-06-17    4470
# 2011-06-10    4466
# 2011-06-24    4464
# 2011-06-13    4448
# 2011-06-09    4438
#               ...
# 2009-05-24     919
# 2009-12-25     908
# 2009-07-04     894
# 2009-11-27     850
# 2009-11-26     782
# Name: FL_DATE, Length: 3955, dtype: int64

# %%
flights.index.nunique()
# Out:
# 3955

# %%
expected_range = pd.date_range(start=flights.index.min(), end=flights.index.max())
expected_range
# Out:
# DatetimeIndex(['2009-01-01', '2009-01-02', '2009-01-03', '2009-01-04',
#                '2009-01-05', '2009-01-06', '2009-01-07', '2009-01-08',
#                '2009-01-09', '2009-01-10',
#                ...
#                '2019-12-22', '2019-12-23', '2019-12-24', '2019-12-25',
#                '2019-12-26', '2019-12-27', '2019-12-28', '2019-12-29',
#                '2019-12-30', '2019-12-31'],
#               dtype='datetime64[ns]', length=4017, freq='D')

# %%
expected_range.difference(flights.index)
# Out:
# DatetimeIndex(['2009-10-01', '2009-10-02', '2009-10-03', '2009-10-04',
#                '2009-10-05', '2009-10-06', '2009-10-07', '2009-10-08',
#                '2009-10-09', '2009-10-10', '2009-10-11', '2009-10-12',
#                '2009-10-13', '2009-10-14', '2009-10-15', '2009-10-16',
#                '2009-10-17', '2009-10-18', '2009-10-19', '2009-10-20',
#                '2009-10-21', '2009-10-22', '2009-10-23', '2009-10-24',
#                '2009-10-25', '2009-10-26', '2009-10-27', '2009-10-28',
#                '2009-10-29', '2009-10-30', '2009-10-31', '2011-07-01',
#                '2011-07-02', '2011-07-03', '2011-07-04', '2011-07-05',
#                '2011-07-06', '2011-07-07', '2011-07-08', '2011-07-09',
#                '2011-07-10', '2011-07-11', '2011-07-12', '2011-07-13',
#                '2011-07-14', '2011-07-15', '2011-07-16', '2011-07-17',
#                '2011-07-18', '2011-07-19', '2011-07-20', '2011-07-21',
#                '2011-07-22', '2011-07-23', '2011-07-24', '2011-07-25',
#                '2011-07-26', '2011-07-27', '2011-07-28', '2011-07-29',
#                '2011-07-30', '2011-07-31'],
#               dtype='datetime64[ns]', freq=None)

# %%
# Out:
# Timedelta('4199 days 00:00:00')

# %%
def clean_flight_data_for_average_daily_delay(flights):
    #Fills in nulls as zero as null means no delay
    flights.fillna(0, inplace=True)
    #Makes FL_DATE column a datetime datatype
    flights.FL_DATE = flights.FL_DATE.astype('datetime64')
    #Makes FL_DATE the index
    flights = flights.set_index('FL_DATE')
    #creates a new column to create a total delay for each observation
    flights['total_delays'] = flights.CARRIER_DELAY + flights.WEATHER_DELAY + flights.NAS_DELAY + flights.SECURITY_DELAY + flights.LATE_AIRCRAFT_DELAY
    #Drops the now used columns
    flights = flights.drop(columns=['OP_CARRIER', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY'])
    
    #impute by mean delay by averaging the "average delays" from the month before and after
    flights_monthly_mean = flights.resample('M').mean().total_delays
    impute_1 = flights_monthly_mean.loc['2009-09-30'] + flights_monthly_mean.loc['2009-11-30'] / 2
    impute_2 = flights_monthly_mean.loc['2011-06-30'] + flights_monthly_mean.loc['2011-08-31'] / 2
    
    #flights_daily_mean = flights.resample('D').mean().total_delays
    #Chose Dataframe
    flights_daily_mean = pd.DataFrame(flights.resample('D').mean().total_delays)
    
    #First imputation
    start_date = datetime.strptime("2009-10-01", "%Y-%m-%d")
    end_date = datetime.strptime("2009-10-31", "%Y-%m-%d")
    
    #Two lists to zip into tuple
    date_list = pd.date_range(start_date, end_date, freq='D')
    impute_1_list = [impute_1] * 31
    
    #Zip them and df them
    list_tuples = list(zip(date_list, impute_1_list))
    list_tuples = pd.DataFrame(list_tuples, columns=['FL_DATE', 'total_delays'])

    #datetime and index 
    list_tuples.FL_DATE = list_tuples.FL_DATE.astype('datetime64')
    list_tuples = list_tuples.set_index('FL_DATE')

    #Append to the daily mean df
    flights_daily_mean = flights_daily_mean.append(list_tuples)

    #Do the same with the second imputation
    start_date_2 = datetime.strptime("2011-07-01", "%Y-%m-%d")
    end_date_2 = datetime.strptime("2011-07-31", "%Y-%m-%d")
    date_list_2 = pd.date_range(start_date_2, end_date_2, freq='D')
    impute_2_list = [impute_2] * 31

    list_tuples_2 = list(zip(date_list_2, impute_2_list))
    list_tuples_2 = pd.DataFrame(list_tuples_2, columns=['FL_DATE', 'total_delays'])

    list_tuples_2.FL_DATE = list_tuples_2.FL_DATE.astype('datetime64')
    list_tuples_2 = list_tuples_2.set_index('FL_DATE')

    flights_daily_mean = flights_daily_mean.append(list_tuples_2)

    flights_daily_mean = flights_daily_mean[flights_daily_mean['total_delays'].notna()]
    
    return flights_daily_mean

# %%
flights_daily_mean = clean_flight_data_for_average_daily_delay(flights)
# Out:
# /var/folders/jv/wt_gjk6n74bcbzwl91qys7sr0000gn/T/ipykernel_3039/3458884136.py:5: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   flights.FL_DATE = flights.FL_DATE.astype('datetime64')
# /var/folders/jv/wt_gjk6n74bcbzwl91qys7sr0000gn/T/ipykernel_3039/3458884136.py:35: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   list_tuples.FL_DATE = list_tuples.FL_DATE.astype('datetime64')
# /var/folders/jv/wt_gjk6n74bcbzwl91qys7sr0000gn/T/ipykernel_3039/3458884136.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   flights_daily_mean = flights_daily_mean.append(list_tuples)
# /var/folders/jv/wt_gjk6n74bcbzwl91qys7sr0000gn/T/ipykernel_3039/3458884136.py:50: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   list_tuples_2.FL_DATE = list_tuples_2.FL_DATE.astype('datetime64')
# /var/folders/jv/wt_gjk6n74bcbzwl91qys7sr0000gn/T/ipykernel_3039/3458884136.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   flights_daily_mean = flights_daily_mean.append(list_tuples_2)

# %%
flights_daily_mean
# Out:
#             total_delays
# FL_DATE
# 2009-01-01      6.232490
# 2009-01-02     21.230769
# 2009-01-03     33.540112
# 2009-01-04     18.426976
# 2009-01-05     11.786416
# ...                  ...
# 2011-07-27     16.770880
# 2011-07-28     16.770880
# 2011-07-29     16.770880
# 2011-07-30     16.770880
# 2011-07-31     16.770880
#
# [4017 rows x 1 columns]

# %%
flights_daily_mean.index.max() - flights_daily_mean.index.min() + pd.Timedelta('1d')
# Out:
# Timedelta('4017 days 00:00:00')

# %%
flights_monthly_mean = flights.resample('M').mean().total_delays

# %%
impute_1 = flights_monthly_mean.loc['2009-09-30'] + flights_monthly_mean.loc['2009-11-30'] / 2
impute_1
# Out:
# 12.184014155094175

# %%
impute_2 = flights_monthly_mean.loc['2011-06-30'] + flights_monthly_mean.loc['2011-08-31'] / 2
impute_2
# Out:
# 16.77087985371366

# %%
flights_daily_mean = pd.DataFrame(flights.resample('D').mean().total_delays)

start_date = datetime.strptime("2009-10-01", "%Y-%m-%d")
end_date = datetime.strptime("2009-10-31", "%Y-%m-%d")
date_list = pd.date_range(start_date, end_date, freq='D')
impute_1_list = [impute_1] * 31

list_tuples = list(zip(date_list, impute_1_list))
list_tuples = pd.DataFrame(list_tuples, columns=['FL_DATE', 'total_delays'])

list_tuples.FL_DATE = list_tuples.FL_DATE.astype('datetime64')
list_tuples = list_tuples.set_index('FL_DATE')

flights_daily_mean = flights_daily_mean.append(list_tuples)


start_date_2 = datetime.strptime("2011-07-01", "%Y-%m-%d")
end_date_2 = datetime.strptime("2011-07-31", "%Y-%m-%d")
date_list_2 = pd.date_range(start_date_2, end_date_2, freq='D')
impute_2_list = [impute_2] * 31

list_tuples_2 = list(zip(date_list_2, impute_2_list))
list_tuples_2 = pd.DataFrame(list_tuples_2, columns=['FL_DATE', 'total_delays'])

list_tuples_2.FL_DATE = list_tuples_2.FL_DATE.astype('datetime64')
list_tuples_2 = list_tuples_2.set_index('FL_DATE')

flights_daily_mean = flights_daily_mean.append(list_tuples_2)

flights_daily_mean.dropna(axis=0)
# Out:
# /var/folders/jv/wt_gjk6n74bcbzwl91qys7sr0000gn/T/ipykernel_3039/844373720.py:11: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   list_tuples.FL_DATE = list_tuples.FL_DATE.astype('datetime64')
# /var/folders/jv/wt_gjk6n74bcbzwl91qys7sr0000gn/T/ipykernel_3039/844373720.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   flights_daily_mean = flights_daily_mean.append(list_tuples)
# /var/folders/jv/wt_gjk6n74bcbzwl91qys7sr0000gn/T/ipykernel_3039/844373720.py:25: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   list_tuples_2.FL_DATE = list_tuples_2.FL_DATE.astype('datetime64')
# /var/folders/jv/wt_gjk6n74bcbzwl91qys7sr0000gn/T/ipykernel_3039/844373720.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   flights_daily_mean = flights_daily_mean.append(list_tuples_2)

# %%
flights_daily_mean.dropna(axis=0)
# Out:
#             total_delays
# FL_DATE
# 2009-01-01      6.232490
# 2009-01-02     21.230769
# 2009-01-03     33.540112
# 2009-01-04     18.426976
# 2009-01-05     11.786416
# ...                  ...
# 2011-07-27     16.770880
# 2011-07-28     16.770880
# 2011-07-29     16.770880
# 2011-07-30     16.770880
# 2011-07-31     16.770880
#
# [4017 rows x 1 columns]

# %%
(flights_daily_mean.index.max())-flights_daily_mean.index.min() + pd.Timedelta('1d')
# Out:
# Timedelta('4017 days 00:00:00')

# %%
flights_daily_mean.loc["2009-10-01":"2009-10-31"]
# Out:
#             total_delays
# FL_DATE
# 2009-10-01           NaN
# 2009-10-02           NaN
# 2009-10-03           NaN
# 2009-10-04           NaN
# 2009-10-05           NaN
# ...                  ...
# 2009-10-27     12.184014
# 2009-10-28     12.184014
# 2009-10-29     12.184014
# 2009-10-30     12.184014
# 2009-10-31     12.184014
#
# [62 rows x 1 columns]

# %%
list_tuples = 0
list_tuples_2 = 0

# %%
list_tuples

# %%
flights_mean = flights.resample('D').mean().total_delays
flights_sum.loc['2009-09-20': '2009-11-15']

# %%
flights_monthly_mean = flights.resample('M').mean().total_delays
_monflights_monthly_mean.head(40)

# %% [markdown]
# ### impute for the two month long gaps by averaging the monthly mean and then the average of the month before and the month after

# %%
impute_1 = flights_monthly_mean.loc['2009-09-30'] + flights_monthly_mean.loc['2009-11-30'] / 2
impute_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 impute_1 = flights_monthly_mean.loc['2009-09-30'] + flights_monthly_mean.loc['2009-11-30'] / 2
#       2 impute_1
#
# NameError: name 'flights_monthly_mean' is not defined

# %%
impute_2 = flights_monthly_mean.loc['2011-06-30'] + flights_monthly_mean.loc['2011-08-31'] / 2
impute_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 impute_2 = flights_monthly_mean.loc['2011-06-30'] + flights_monthly_mean.loc['2011-08-31'] / 2
#       2 impute_2
#
# NameError: name 'flights_monthly_mean' is not defined

# %%
flights.resample('W').sum().total_delays

# %%
flights.resample('M').sum().total_delays

# %%
plt.figure(figsize=(10,6))

flights.resample('D').sum().total_delays.plot(label='daily')
# flights.resample('W').sum().total_delays.plot(label='weekly')
# flights.resample('M').sum().total_delays.plot(label='monthly')
# flights.resample('D').sum().total_delays.plot(label='yearly')


plt.title('Total Delay by Day')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))

# flights.resample('D').sum().total_delays.plot(label='daily')
flights.resample('W').sum().total_delays.plot(label='weekly')
# flights.resample('M').sum().total_delays.plot(label='monthly')
# flights.resample('D').sum().total_delays.plot(label='yearly')


plt.title('Total Delay By Week')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))

# flights.resample('D').sum().total_delays.plot(label='daily')
# flights.resample('W').sum().total_delays.plot(label='weekly')
flights.resample('M').mean().total_delays.plot(label='monthly')
# flights.resample('D').sum().total_delays.plot(label='yearly')


plt.title('Total Delay By Month')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))

# flights.resample('D').sum().total_delays.plot(label='daily')
# flights.resample('W').sum().total_delays.plot(label='weekly')
# flights.resample('M').sum().total_delays.plot(label='monthly')
flights.resample('Y').sum().total_delays.plot(label='yearly')


plt.title('Total Delay By Year')
plt.legend()
plt.show()
